# %% [markdown]
# chrome://dino/

# %%
from __future__ import division

# %%
from autopy import *
import gc
from PIL import Image, ImageOps
import numpy as np
import time
import random
from matplotlib import cm
import os.path

# %%
import win32gui, win32com.client
import re

class WindowMgr:
    """Encapsulates some calls to the winapi for window management"""
    def __init__ (self):
        """Constructor"""
        self._handle = None

    def find_window(self, class_name, window_name = None):
        """find a window by its class_name"""
        self._handle = win32gui.FindWindow(class_name, window_name)

    def _window_enum_callback(self, hwnd, wildcard):
        '''Pass to win32gui.EnumWindows() to check all the opened windows'''
        if re.match(wildcard, str(win32gui.GetWindowText(hwnd))) != None:
            self._handle = hwnd

    def find_window_wildcard(self, wildcard):
        self._handle = None
        win32gui.EnumWindows(self._window_enum_callback, wildcard)
        
   
    def find_window_position_size(self):
        rect = win32gui.GetWindowRect(self._handle)
        x = rect[0]
        y = rect[1]
        w = rect[2] - x
        h = rect[3] - y
        return (x , y , w , h)
    
    def set_foreground(self):
        """put the window in the foreground"""
        shell = win32com.client.Dispatch("WScript.Shell")
        shell.SendKeys('%')
        win32gui.SetForegroundWindow(self._handle)
        
    def get_screen_image(self):
        x , y , w , h = self.find_window_position_size()
        bmp = bitmap.capture_screen()
        bmp.save('screen.png')
        img = Image.open('screen.png')
        img = img.crop((x + 10 , y + 150  , x+w -10 , y+ h - 200 ))
        img = img.resize((256,256)).convert('L')
        img = ImageOps.invert(img)
        shape = [(0, 55), (w, 50)]
        img = np.asarray(img)
        img = img / 255.0
        img = img.reshape((256,256))
        return img

# %%
def is_done(image):
    avg = np.average(image[52:55 , 0:255])
    if avg < 0.05:
        return True 
    else:
        return False

# %%
def key_press(code):
        key.toggle(code , True)
        key.toggle(code , False)

# %%
def key_tap(code):
    key.tap(code , delay = 0.00000001)
#     key.toggle(code , True)
#     time.sleep(0.000001)
#     key.toggle(code , False)

# %%
class Gym:
    def __init__(self):
        self.window = None
        
    def reset(self):
        self.window = WindowMgr()
        self.window.find_window_wildcard(".*chrome://dino/.*")
        self.window.set_foreground()
        key_press(key.Code.F5)
        time.sleep(0.08)
        key_press(key.Code.SPACE)
        img = np.zeros((256,256,3))
        return img
    
    def step(self , action , delay):
        
        
        if action == 2 :
            key_press(key.Code.UP_ARROW)
        if action == 0 :
            key_tap(key.Code.UP_ARROW)
        if action == 3 :
            key_press(key.Code.DOWN_ARROW)
        if action == 1 :
            pass
#         delay = 0 if 0.1 - delay <=0 else 0.1 - delay
#         time.sleep(delay)
        img1 = self.window.get_screen_image()
        time.sleep(1/50)
        img2 = self.window.get_screen_image()
        time.sleep(1/50)
        img3 = self.window.get_screen_image()
        
        img = np.stack([img1 , img2 , img3] , axis=-1)

        done = is_done(img3)


        if done : 
            reward =  +1
        else:
            reward = -1
  
        return img , done , reward

# %%
env = Gym()
# env.reset()
# done = True
# while done :
#     observation,done,reward = env.step(np.random.randint(0,3))
# #     im = Image.fromarray(np.uint8(cm.gist_earth(observation)*255))
# #     display(im)

# %%
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
class iDQNAgent:
    def __init__(self, state_shape , action_no, memory_size = 1000):
        self.action_no = action_no
        self.memory = []
        self.memory_size = memory_size
        self.gamma = 0.9
        self.epsilon = 1.0
        self.epsilon_min = 0.1
        self.epsilon_decay = 0.999
        self.learning_rate = 1e-4
        self.sync_nets = 50

        
        self.state_shape = state_shape

        
        self.q_model = self.build_model(state_shape , action_no)
        self.q_model.compile(loss='mse' , optimizer=Adam(learning_rate=self.learning_rate))
        
#         if os.path.exists('q_model.h5'):
#             self.q_model.load_weights('q_model.h5')
            
        self.target_q_model = self.build_model(state_shape , action_no)
        
        self.update_weights()
    
        
        ####################################################
    def build_model(self ,input_shape , n_outputs):
        inputs = layers.Input(shape = input_shape , name='state')
        x = layers.Conv2D(64, (4,4) , strides=4 ,padding='same' , kernel_initializer='he_normal')(inputs)
        x = layers.Activation('relu')(x)
        x = layers.BatchNormalization()(x)
        
        x = layers.Conv2D(64, (4,4) , strides=2 ,padding='same' , kernel_initializer='he_normal')(x)
        x = layers.Activation('relu')(x)
        x = layers.BatchNormalization()(x)
        
        x = layers.Conv2D(64, (3,3) , strides=1 ,padding='same' , kernel_initializer='he_normal')(x)
        x = layers.Activation('relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.MaxPooling2D()(x)
        
        x = layers.Conv2D(64, (3,3) , strides=1 ,padding='same' , kernel_initializer='he_normal')(x)
        x = layers.Activation('relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.MaxPooling2D()(x)
        
        x = layers.Conv2D(64, (3,3) , strides=1 ,padding='same' , kernel_initializer='he_normal')(x)
        x = layers.Activation('relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.MaxPooling2D()(x)
   
        x = layers.Flatten()(x) 

        x = layers.Dense(512 , activation='relu')(x)
        x = layers.Dense(256 , activation='relu')(x)
        x = layers.Dense(n_outputs , activation='linear' , name = 'action')(x)
        model = Model(inputs , x)
#         model.summary()
        return model
    
        #####################################################
    def act(self , state):
        
        if np.random.rand() < self.epsilon:
            return np.random.randint(0 , self.action_no) , 0
            
        t = time.time()
        q_values = self.q_model.predict(np.expand_dims(state , axis=0))
        action = np.argmax(q_values[0])
        print("action {} q-value {} ".format(action , q_values[0][action] ))
        return action , time.time()-t
    
        ######################################################
    def remember(self, state, action, reward , next_state , done):
        item = (state , action , reward , next_state ,done)
        if len(self.memory) > self.memory_size :
            self.memory.pop(0)
        self.memory.append(item)
        
        #######################################################
    def get_target_q_value(self, next_state, reward , double):
        if double :
            action = np.argmax(self.q_model.predict(next_state[0]))
            q_value = self.target_q_model.predict(next_state)[0][action]
        else :
            q_value = np.amax(self.target_q_model.predict(next_state)[0])
        
        q_value *= self.gamma
        q_value += reward
        return q_value
    
        ########################################################
    def replay(self , batch_size):
        sars_batch = random.sample(self.memory , batch_size)
       
        state_batch , q_value_batch = [] , []
        for state, action, reward, next_state, done in sars_batch:
            
            q_values = self.q_model.predict(np.expand_dims(state , axis=0))
            
            q_value = self.get_target_q_value(np.expand_dims(next_state , axis=0), reward, False)
            # ??????????
            q_values[0][action] = reward if done==False else q_value
            
            state_batch.append(state)
            q_value_batch.append(q_values[0])
        
#         print('q-values mean: {}'.format(np.mean(q_value_batch)))
        
        hist = self.q_model.fit(np.array(state_batch) , 
                             np.array(q_value_batch),
                             batch_size = batch_size,
                            epochs = 1,
                            verbose = 0)
                
        return hist.history['loss'][0]
       
       ######################################################

       ######################################################
    def update_epsilon(self ):
#         self.epsilon = self.epsilon_min + (1 - self.epsilon_min)* np.exp(-self.epsilon_decay * episode)
        self.epsilon = self.epsilon  * self.epsilon_decay
        if self.epsilon < self.epsilon_min :
            self.epsilon = self.epsilon_min

        ########################################################
    def update_weights(self):
            self.target_q_model.set_weights(self.q_model.get_weights())

# %%
episode_count = 500000
time_steps =    100000
batch_size = 64

# %%
agent = iDQNAgent((256 , 256 , 3) ,4)

# %%
all_rewards = []
all_losses =  []
loss = 0

for episode in range(episode_count):
    state = env.reset()
    done = True
    total_reward = 0

    for t in range(time_steps) :
        action , delay = agent.act(state)
        next_state , done ,reward = env.step(action , delay)
#         if not done:
#             reward -= 100
        agent.remember(state , action , reward , next_state , done)
        state = next_state
        total_reward += reward
   
        if not done : 
            break
            
    if len(agent.memory) >= batch_size:
        loss = agent.replay(batch_size)
        all_losses.append(loss) 
        
    agent.update_epsilon()
    
    if episode % agent.sync_nets == 0:
        agent.update_weights()
        print('update weights')
        print("Avarage loss {}".format(np.mean(np.array(all_losses[-50:]))) )
        print("Avarage reward {}".format(np.mean(np.array(all_rewards[-50:]))) )
        
    if episode % 1000 == 0:
        agent.q_model.save_weights('q_model.h5')
        
    print("episode {} reward {} loss {} epsilon {} memory {}".format(episode , total_reward, loss, agent.epsilon , len(agent.memory)))
    all_rewards.append(total_reward)
    
    if loss > 1000 :
        break
# Out:
# update weights
# Avarage loss nan
# episode 0 reward 16 loss 0 epsilon 0.999 memory 18
# C:\Users\SERVER\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\SERVER\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# episode 1 reward 16 loss 0 epsilon 0.998001 memory 36
# episode 2 reward 20 loss 0 epsilon 0.997002999 memory 58
# episode 3 reward 16 loss 2.8090434074401855 epsilon 0.996005996001 memory 76
# episode 4 reward 17 loss 1.001000165939331 epsilon 0.995009990004999 memory 95
# episode 5 reward 19 loss 0.4771028459072113 epsilon 0.994014980014994 memory 116
# episode 6 reward 14 loss 0.653719425201416 epsilon 0.993020965034979 memory 132
# episode 7 reward 17 loss 0.8137952089309692 epsilon 0.9920279440699441 memory 151
# episode 8 reward 20 loss 0.8869400024414062 epsilon 0.9910359161258742 memory 173
# episode 9 reward 22 loss 0.6457735300064087 epsilon 0.9900448802097482 memory 197
# action 3 q-value 0.22636835277080536
# episode 10 reward 22 loss 0.4268605411052704 epsilon 0.9890548353295385 memory 221
# episode 11 reward 16 loss 0.34776002168655396 epsilon 0.988065780494209 memory 239
# episode 12 reward 14 loss 0.3069556951522827 epsilon 0.9870777147137147 memory 255
# episode 13 reward 16 loss 0.3451778292655945 epsilon 0.986090636999001 memory 273
# episode 91 reward 14 loss 0.1984511911869049 epsilon 0.9120631656822724 memory 1794
# action 1 q-value 0.4472028315067291
# episode 92 reward 16 loss 0.19401612877845764 epsilon 0.9111511025165902 memory 1812
# action 2 q-value 0.4031820297241211
# action 3 q-value 0.4733826816082001
# episode 93 reward 16 loss 0.17760033905506134 epsilon 0.9102399514140735 memory 1830
# action 2 q-value 0.4013693630695343
# action 3 q-value 0.4792928397655487
# episode 94 reward 16 loss 0.1858523190021515 epsilon 0.9093297114626595 memory 1848
# action 1 q-value 0.3196118474006653
# action 1 q-value 0.38817888498306274
# episode 95 reward 18 loss 0.1813374161720276 epsilon 0.9084203817511969 memory 1868
# action 3 q-value 0.33896297216415405
# action 1 q-value 0.42593616247177124
# action 1 q-value 0.36886969208717346
# episode 96 reward 28 loss 0.1877639889717102 epsilon 0.9075119613694457 memory 1898
# action 1 q-value 0.4254244863986969
# action 3 q-value 0.4284815490245819
# action 3 q-value 0.3384449779987335
# episode 97 reward 16 loss 0.18435858190059662 epsilon 0.9066044494080763 memory 1916
# episode 98 reward 16 loss 0.2040361762046814 epsilon 0.9056978449586682 memory 1934
# action 1 q-value 0.4700216054916382
# action 3 q-value 0.43568384647369385
# action 1 q-value 0.2959611713886261
# episode 99 reward 14 loss 0.163857102394104 epsilon 0.9047921471137096 memory 1950
# action 1 q-value 0.3698374629020691
# action 1 q-value 0.2835853397846222
# update weights
# Avarage loss 0.21086180359125137
# episode 100 reward 15 loss 0.1685674786567688 epsilon 0.9038873549665959 memory 1967
# episode 101 reward 18 loss 0.20950846374034882 epsilon 0.9029834676116293 memory 1987
# action 0 q-value 0.404245525598526
# action 3 q-value 0.38238221406936646
# action 3 q-value 0.3546385169029236
# action 1 q-value 0.4547288417816162
# episode 102 reward 18 loss 0.19253231585025787 epsilon 0.9020804841440176 memory 2007
# action 1 q-value 0.5547041296958923
# action 3 q-value 0.40919026732444763
# action 1 q-value 0.4057766795158386
# action 3 q-value 0.3920290768146515
# episode 103 reward 13 loss 0.2149694561958313 epsilon 0.9011784036598737 memory 2022
# action 0 q-value 0.4605293273925781
# action 3 q-value 0.3681398928165436
# episode 104 reward 16 loss 0.21095865964889526 epsilon 0.9002772252562138 memory 2040
# action 3 q-value 0.44490158557891846
# action 3 q-value 0.4744204580783844
# episode 105 reward 14 loss 0.22008053958415985 epsilon 0.8993769480309576 memory 2056
# action 3 q-value 0.5664786696434021
# action 1 q-value 0.4216470420360565
# episode 106 reward 18 loss 0.19498521089553833 epsilon 0.8984775710829266 memory 2076
# action 1 q-value 0.48882725834846497
# action 1 q-value 0.3189636468887329
# episode 107 reward 14 loss 0.2027709186077118 epsilon 0.8975790935118436 memory 2092
# episode 108 reward 16 loss 0.1995958387851715 epsilon 0.8966815144183318 memory 2110
# action 1 q-value 0.6221585869789124
# action 1 q-value 0.33368346095085144
# episode 109 reward 14 loss 0.1944369673728943 epsilon 0.8957848329039134 memory 2126
# action 1 q-value 0.5223219990730286
# action 1 q-value 0.47952765226364136
# action 1 q-value 0.5180121660232544
# episode 110 reward 21 loss 0.19097840785980225 epsilon 0.8948890480710096 memory 2149
# action 1 q-value 0.6356680989265442
# action 1 q-value 0.5121108889579773
# action 3 q-value 0.5668327808380127
# action 3 q-value 0.4939659833908081
# action 1 q-value 0.41627535223960876
# episode 111 reward 22 loss 0.20525678992271423 epsilon 0.8939941590229386 memory 2173
# episode 112 reward 16 loss 0.18867173790931702 epsilon 0.8931001648639156 memory 2191
# action 1 q-value 0.5746445059776306
# action 3 q-value 0.49699270725250244
# episode 113 reward 16 loss 0.19420138001441956 epsilon 0.8922070646990518 memory 2209
# action 1 q-value 0.548642635345459
# episode 114 reward 17 loss 0.19763994216918945 epsilon 0.8913148576343527 memory 2228
# action 1 q-value 0.47179755568504333
# episode 115 reward 20 loss 0.23750168085098267 epsilon 0.8904235427767183 memory 2250
# action 1 q-value 0.6107897758483887
# action 3 q-value 0.7126387357711792
# action 3 q-value 0.5638696551322937
# action 3 q-value 0.6030355095863342
# episode 116 reward 16 loss 0.19576919078826904 epsilon 0.8895331192339416 memory 2268
# action 3 q-value 0.6210467219352722
# action 3 q-value 0.5287960171699524
# episode 117 reward 14 loss 0.18558302521705627 epsilon 0.8886435861147077 memory 2284
# action 1 q-value 0.6168274283409119
# action 3 q-value 0.6570325493812561
# action 1 q-value 0.5021368861198425
# episode 118 reward 16 loss 0.18759270012378693 epsilon 0.887754942528593 memory 2302
# action 0 q-value 0.5877392888069153
# action 1 q-value 0.5946915745735168
# action 1 q-value 0.4112269878387451
# episode 119 reward 16 loss 0.17468202114105225 epsilon 0.8868671875860644 memory 2320
# action 3 q-value 0.4363868832588196
# episode 120 reward 18 loss 0.19065485894680023 epsilon 0.8859803203984784 memory 2340
# episode 121 reward 14 loss 0.18900977075099945 epsilon 0.88509434007808 memory 2356
# action 1 q-value 0.6873283982276917
# action 3 q-value 0.5326178669929504
# episode 122 reward 16 loss 0.2293051779270172 epsilon 0.8842092457380019 memory 2374
# action 1 q-value 0.6726897358894348
# action 3 q-value 0.5991716384887695
# episode 123 reward 16 loss 0.20649006962776184 epsilon 0.8833250364922639 memory 2392
# action 1 q-value 0.6211338639259338
# action 1 q-value 0.7104765772819519
# action 3 q-value 0.5793706178665161
# episode 124 reward 16 loss 0.17432741820812225 epsilon 0.8824417114557717 memory 2410
# action 3 q-value 0.5953911542892456
# episode 125 reward 16 loss 0.1744820475578308 epsilon 0.8815592697443159 memory 2428
# episode 126 reward 14 loss 0.20295582711696625 epsilon 0.8806777104745716 memory 2444
# action 1 q-value 0.8009722828865051
# action 1 q-value 0.7040941715240479
# action 1 q-value 0.6508010625839233
# episode 127 reward 16 loss 0.20684567093849182 epsilon 0.8797970327640969 memory 2462
# action 1 q-value 0.7728115916252136
# action 1 q-value 0.5619405508041382
# episode 128 reward 16 loss 0.16960963606834412 epsilon 0.8789172357313328 memory 2480
# action 1 q-value 0.7951055765151978
# action 3 q-value 0.6244256496429443
# action 3 q-value 0.6764461994171143
# action 1 q-value 0.6128898859024048
# action 3 q-value 0.3980166018009186
# episode 129 reward 15 loss 0.19633278250694275 epsilon 0.8780383184956015 memory 2497
# action 1 q-value 0.7745157480239868
# action 1 q-value 0.7152303457260132
# action 3 q-value 0.6003177762031555
# action 1 q-value 0.6607311964035034
# action 3 q-value 0.6118137836456299
# action 3 q-value 0.399844765663147
# episode 130 reward 15 loss 0.16882045567035675 epsilon 0.8771602801771059 memory 2514
# action 3 q-value 0.6054582595825195
# action 1 q-value 0.5427331328392029
# action 3 q-value 0.6026658415794373
# episode 131 reward 21 loss 0.18142709136009216 epsilon 0.8762831198969288 memory 2537
# action 1 q-value 0.7426949739456177
# action 3 q-value 0.7630814909934998
# action 1 q-value 0.6421065926551819
# episode 132 reward 16 loss 0.21465516090393066 epsilon 0.8754068367770318 memory 2555
# action 1 q-value 0.8053328394889832
# episode 133 reward 16 loss 0.17770645022392273 epsilon 0.8745314299402548 memory 2573
# action 1 q-value 0.7383425831794739
# action 3 q-value 0.6285786032676697
# action 1 q-value 0.6017354130744934
# episode 134 reward 15 loss 0.19036993384361267 epsilon 0.8736568985103146 memory 2590
# action 1 q-value 0.7156360745429993
# episode 135 reward 18 loss 0.17832909524440765 epsilon 0.8727832416118043 memory 2610
# action 3 q-value 0.6526181101799011
# action 1 q-value 0.6813874244689941
# action 2 q-value 0.353812575340271
# episode 136 reward 16 loss 0.17433993518352509 epsilon 0.8719104583701925 memory 2628
# action 1 q-value 0.7914979457855225
# episode 137 reward 16 loss 0.19918106496334076 epsilon 0.8710385479118223 memory 2646
# action 1 q-value 0.7683956027030945
# action 1 q-value 0.6643982529640198
# episode 138 reward 16 loss 0.19893506169319153 epsilon 0.8701675093639105 memory 2664
# action 1 q-value 0.7863454222679138
# action 3 q-value 0.5776425004005432
# action 1 q-value 0.5730797052383423
# episode 139 reward 18 loss 0.1450560986995697 epsilon 0.8692973418545467 memory 2684
# action 1 q-value 0.6570332050323486
# episode 140 reward 16 loss 0.15829919278621674 epsilon 0.8684280445126921 memory 2702
# action 1 q-value 0.8366509675979614
# episode 141 reward 16 loss 0.18297038972377777 epsilon 0.8675596164681794 memory 2720
# action 1 q-value 0.707247257232666
# episode 142 reward 16 loss 0.20537157356739044 epsilon 0.8666920568517111 memory 2738
# action 1 q-value 0.7153553366661072
# action 1 q-value 0.5780773162841797
# episode 143 reward 14 loss 0.2053183615207672 epsilon 0.8658253647948594 memory 2754
# action 1 q-value 0.8130414485931396
# action 3 q-value 0.6152886152267456
# action 3 q-value 0.5887974500656128
# action 1 q-value 0.6944380402565002
# episode 144 reward 16 loss 0.13759729266166687 epsilon 0.8649595394300645 memory 2772
# action 0 q-value 0.47139620780944824
# episode 145 reward 25 loss 0.1829349249601364 epsilon 0.8640945798906344 memory 2799
# action 3 q-value 0.6620501279830933
# episode 146 reward 16 loss 0.13879050314426422 epsilon 0.8632304853107438 memory 2817
# action 1 q-value 0.8180258870124817
# action 1 q-value 0.521813690662384
# action 0 q-value 0.5129106640815735
# episode 147 reward 15 loss 0.16810092329978943 epsilon 0.862367254825433 memory 2834
# episode 183 reward 14 loss 0.17523787915706635 epsilon 0.831859218194368 memory 3532
# action 1 q-value 1.1733129024505615
# episode 184 reward 14 loss 0.1831965446472168 epsilon 0.8310273589761736 memory 3548
# action 1 q-value 1.1105278730392456
# action 1 q-value 1.2778502702713013
# action 3 q-value 0.9151819348335266
# episode 185 reward 18 loss 0.18411855399608612 epsilon 0.8301963316171974 memory 3568
# action 3 q-value 0.8086863160133362
# action 3 q-value 0.8877740502357483
# episode 186 reward 14 loss 0.18618294596672058 epsilon 0.8293661352855802 memory 3584
# action 3 q-value 0.8519160151481628
# action 3 q-value 0.9054189920425415
# episode 187 reward 21 loss 0.1891573965549469 epsilon 0.8285367691502946 memory 3607
# action 3 q-value 0.7605577111244202
# action 3 q-value 0.8023042678833008
# action 3 q-value 0.5693541765213013
# action 3 q-value 0.5836884379386902
# episode 188 reward 21 loss 0.18685145676136017 epsilon 0.8277082323811443 memory 3630
# action 1 q-value 1.0840801000595093
# action 3 q-value 0.9093528985977173
# action 3 q-value 0.7011043429374695
# episode 189 reward 15 loss 0.18025977909564972 epsilon 0.8268805241487632 memory 3647
# action 1 q-value 1.1163338422775269
# action 3 q-value 0.8651353120803833
# action 3 q-value 0.8233347535133362
# action 3 q-value 0.7213428616523743
# action 3 q-value 0.450543612241745
# episode 190 reward 15 loss 0.18811321258544922 epsilon 0.8260536436246144 memory 3664
# action 1 q-value 1.2463237047195435
# action 1 q-value 1.187013864517212
# action 3 q-value 0.8537145256996155
# episode 191 reward 16 loss 0.17200635373592377 epsilon 0.8252275899809898 memory 3682
# action 1 q-value 1.1020734310150146
# action 3 q-value 0.7431052327156067
# action 2 q-value 0.6072372794151306
# action 1 q-value 0.7397491931915283
# episode 192 reward 15 loss 0.1856749951839447 epsilon 0.8244023623910088 memory 3699
# action 1 q-value 1.0880937576293945
# action 3 q-value 0.7379058003425598
# episode 193 reward 18 loss 0.19867664575576782 epsilon 0.8235779600286178 memory 3719
# action 1 q-value 1.2677979469299316
# action 1 q-value 1.3313713073730469
# action 3 q-value 0.87755286693573
# action 3 q-value 0.8473620414733887
# action 3 q-value 0.5938725471496582
# action 1 q-value 0.6009072661399841
# episode 194 reward 15 loss 0.14410580694675446 epsilon 0.8227543820685892 memory 3736
# action 1 q-value 1.0406934022903442
# action 3 q-value 0.5936437845230103
# action 1 q-value 0.8578671216964722
# episode 195 reward 16 loss 0.178868368268013 epsilon 0.8219316276865206 memory 3754
# action 3 q-value 0.7515484690666199
# action 1 q-value 0.853643536567688
# action 1 q-value 0.6765191555023193
# episode 196 reward 16 loss 0.16813373565673828 epsilon 0.8211096960588341 memory 3772
# action 1 q-value 1.0126991271972656
# action 3 q-value 0.7101082801818848
# action 3 q-value 0.8086453080177307
# action 1 q-value 0.8326750993728638
# episode 197 reward 15 loss 0.16073384881019592 epsilon 0.8202885863627752 memory 3789
# action 1 q-value 1.130627989768982
# action 1 q-value 1.1514434814453125
# action 1 q-value 1.2562192678451538
# action 3 q-value 0.7509515285491943
# action 3 q-value 0.7294748425483704
# action 3 q-value 0.7591167092323303
# action 3 q-value 0.730981707572937
# action 2 q-value 0.6241967678070068
# episode 198 reward 17 loss 0.19454467296600342 epsilon 0.8194682977764125 memory 3808
# action 1 q-value 1.1546276807785034
# action 0 q-value 0.5943845510482788
# episode 199 reward 16 loss 0.16316959261894226 epsilon 0.818648829478636 memory 3826
# action 3 q-value 0.7724037766456604
# update weights
# Avarage loss 0.1813826447725296
# episode 200 reward 16 loss 0.14844873547554016 epsilon 0.8178301806491574 memory 3844
# action 1 q-value 1.1111794710159302
# action 1 q-value 1.1106512546539307
# action 1 q-value 1.0533640384674072
# action 2 q-value 0.7443149089813232
# action 3 q-value 0.6569095253944397
# episode 201 reward 19 loss 0.19162720441818237 epsilon 0.8170123504685082 memory 3865
# action 1 q-value 1.231597900390625
# action 3 q-value 0.7729780077934265
# episode 202 reward 14 loss 0.21303534507751465 epsilon 0.8161953381180397 memory 3881
# action 1 q-value 0.9400309324264526
# action 1 q-value 1.2302623987197876
# action 3 q-value 0.9090516567230225
# action 3 q-value 0.9297665357589722
# episode 203 reward 14 loss 0.19063404202461243 epsilon 0.8153791427799216 memory 3897
# action 3 q-value 0.8527151942253113
# action 3 q-value 0.7085792422294617
# action 2 q-value 0.6340056657791138
# episode 204 reward 20 loss 0.2084711343050003 epsilon 0.8145637636371417 memory 3919
# action 1 q-value 1.266575813293457
# action 2 q-value 0.7825129628181458
# episode 205 reward 16 loss 0.22204385697841644 epsilon 0.8137491998735046 memory 3937
# action 0 q-value 1.1761078834533691
# action 1 q-value 1.1494661569595337
# action 3 q-value 0.8917074203491211
# action 0 q-value 0.6992402076721191
# action 0 q-value 0.7156670689582825
# episode 206 reward 18 loss 0.19641602039337158 epsilon 0.812935450673631 memory 3957
# action 3 q-value 0.7710739970207214
# action 0 q-value 0.7558445930480957
# action 2 q-value 0.7347460985183716
# action 2 q-value 0.7588242292404175
# episode 207 reward 21 loss 0.2125256359577179 epsilon 0.8121225152229574 memory 3980
# action 3 q-value 0.8849350810050964
# action 0 q-value 0.8130253553390503
# action 0 q-value 0.8352463841438293
# action 0 q-value 0.7354152798652649
# action 3 q-value 0.7114900946617126
# episode 208 reward 24 loss 0.2101331353187561 epsilon 0.8113103927077344 memory 4006
# action 0 q-value 0.9452094435691833
# action 2 q-value 0.9157018065452576
# action 3 q-value 0.692152202129364
# action 0 q-value 0.7438070178031921
# episode 209 reward 21 loss 0.25323158502578735 epsilon 0.8104990823150267 memory 4029
# action 3 q-value 0.9258438348770142
# action 3 q-value 0.7431439757347107
# action 0 q-value 0.8342353701591492
# action 2 q-value 0.8399150967597961
# episode 210 reward 15 loss 0.2077058106660843 epsilon 0.8096885832327116 memory 4046
# action 0 q-value 1.2367095947265625
# action 2 q-value 1.1076600551605225
# action 3 q-value 0.8059977889060974
# action 2 q-value 0.7751977443695068
# action 0 q-value 0.8030316233634949
# action 2 q-value 0.9163942337036133
# action 2 q-value 0.6880380511283875
# episode 211 reward 15 loss 0.19119928777217865 epsilon 0.8088788946494789 memory 4063
# action 2 q-value 1.0842835903167725
# action 2 q-value 1.2504554986953735
# action 2 q-value 0.703281581401825
# action 3 q-value 0.6516811847686768
# episode 212 reward 14 loss 0.17147937417030334 epsilon 0.8080700157548294 memory 4079
# action 3 q-value 1.089443325996399
# action 2 q-value 0.8917717933654785
# episode 213 reward 16 loss 0.21201655268669128 epsilon 0.8072619457390746 memory 4097
# action 2 q-value 1.121988296508789
# action 3 q-value 0.8529139161109924
# action 3 q-value 0.9225586652755737
# action 0 q-value 0.709978461265564
# action 0 q-value 0.8690651059150696
# action 0 q-value 0.7025014162063599
# action 0 q-value 0.7164654731750488
# episode 214 reward 32 loss 0.20814666152000427 epsilon 0.8064546837933355 memory 4131
# action 2 q-value 1.218662977218628
# action 2 q-value 1.3284952640533447
# action 2 q-value 0.7627349495887756
# action 0 q-value 1.070361614227295
# action 1 q-value 0.7899919748306274
# episode 215 reward 20 loss 0.19143317639827728 epsilon 0.8056482291095421 memory 4153
# action 1 q-value 1.3006633520126343
# action 3 q-value 0.9472669959068298
# action 2 q-value 1.0002124309539795
# action 0 q-value 0.7851676344871521
# episode 216 reward 19 loss 0.1811436414718628 epsilon 0.8048425808804326 memory 4174
# action 2 q-value 0.7896655797958374
# action 0 q-value 0.7372251749038696
# episode 217 reward 20 loss 0.16742923855781555 epsilon 0.8040377382995522 memory 4196
# action 2 q-value 1.0221941471099854
# action 2 q-value 0.926839292049408
# action 3 q-value 0.9952519536018372
# episode 218 reward 16 loss 0.18551544845104218 epsilon 0.8032337005612527 memory 4214
# action 1 q-value 1.3085099458694458
# action 1 q-value 1.1560442447662354
# action 3 q-value 0.8233738541603088
# action 3 q-value 0.7552511096000671
# episode 219 reward 15 loss 0.20159658789634705 epsilon 0.8024304668606914 memory 4231
# action 2 q-value 0.8614901304244995
# episode 220 reward 18 loss 0.19732025265693665 epsilon 0.8016280363938307 memory 4251
# action 1 q-value 1.2837474346160889
# action 1 q-value 1.3732482194900513
# action 1 q-value 1.473852515220642
# action 3 q-value 0.9490988254547119
# action 3 q-value 0.8301050066947937
# action 2 q-value 0.9045848846435547
# action 2 q-value 0.8357861042022705
# action 0 q-value 0.7418908476829529
# episode 221 reward 15 loss 0.1747840940952301 epsilon 0.8008264083574369 memory 4268
# action 1 q-value 1.1524879932403564
# action 3 q-value 0.7981902360916138
# action 3 q-value 0.9381012320518494
# action 1 q-value 0.8737371563911438
# episode 222 reward 17 loss 0.2214648425579071 epsilon 0.8000255819490795 memory 4287
# action 2 q-value 0.7581444978713989
# action 3 q-value 0.57573002576828
# episode 223 reward 16 loss 0.2164071649312973 epsilon 0.7992255563671304 memory 4305
# action 1 q-value 1.172673225402832
# action 1 q-value 1.4185075759887695
# action 1 q-value 0.7942344546318054
# action 0 q-value 0.8862717151641846
# action 1 q-value 0.8787906169891357
# action 2 q-value 0.7058985829353333
# episode 224 reward 20 loss 0.1952144056558609 epsilon 0.7984263308107633 memory 4327
# action 2 q-value 0.9978370070457458
# action 1 q-value 0.932748019695282
# action 3 q-value 0.9878559708595276
# action 0 q-value 0.7936411499977112
# action 0 q-value 0.694091260433197
# action 2 q-value 0.7009027004241943
# episode 225 reward 18 loss 0.16563549637794495 epsilon 0.7976279044799526 memory 4347
# action 3 q-value 0.8801587820053101
# action 3 q-value 0.9121717214584351
# action 1 q-value 0.8509816527366638
# action 0 q-value 0.9493345022201538
# action 3 q-value 0.8374064564704895
# episode 226 reward 16 loss 0.15965871512889862 epsilon 0.7968302765754727 memory 4365
# action 3 q-value 0.7630192041397095
# action 0 q-value 0.937511682510376
# episode 227 reward 14 loss 0.2531238794326782 epsilon 0.7960334462988972 memory 4381
# action 1 q-value 1.4030920267105103
# action 0 q-value 1.0693215131759644
# action 1 q-value 0.8674540519714355
# action 3 q-value 0.9074837565422058
# action 0 q-value 0.9006239175796509
# action 2 q-value 0.8784608840942383
# episode 228 reward 18 loss 0.16609710454940796 epsilon 0.7952374128525983 memory 4401
# action 1 q-value 1.3617973327636719
# action 2 q-value 0.9556740522384644
# action 3 q-value 0.6931139230728149
# action 0 q-value 0.8570519089698792
# action 2 q-value 0.8387941718101501
# episode 229 reward 16 loss 0.16665787994861603 epsilon 0.7944421754397457 memory 4419
# action 0 q-value 0.8588629364967346
# action 3 q-value 0.9718518853187561
# action 1 q-value 0.7780116200447083
# episode 230 reward 16 loss 0.20596641302108765 epsilon 0.7936477332643059 memory 4437
# action 1 q-value 1.3983498811721802
# action 1 q-value 1.4022440910339355
# action 0 q-value 0.7803640961647034
# action 0 q-value 0.8772490620613098
# action 3 q-value 0.8267533779144287
# action 0 q-value 0.9285587072372437
# action 2 q-value 0.7953537106513977
# episode 231 reward 16 loss 0.18800640106201172 epsilon 0.7928540855310416 memory 4455
# action 1 q-value 1.424540638923645
# action 3 q-value 0.7127010226249695
# action 3 q-value 0.945481538772583
# action 0 q-value 0.8153104186058044
# action 2 q-value 0.7338237166404724
# action 0 q-value 0.6567307710647583
# episode 232 reward 21 loss 0.17478108406066895 epsilon 0.7920612314455105 memory 4478
# action 3 q-value 0.8366167545318604
# action 3 q-value 0.8886871933937073
# action 1 q-value 0.8533018231391907
# episode 233 reward 16 loss 0.21434101462364197 epsilon 0.7912691702140651 memory 4496
# action 1 q-value 1.1978144645690918
# action 1 q-value 1.5240598917007446
# action 2 q-value 0.8512735366821289
# action 2 q-value 0.8016433715820312
# episode 234 reward 17 loss 0.2090950459241867 epsilon 0.790477901043851 memory 4515
# action 1 q-value 1.332722544670105
# action 2 q-value 1.0060261487960815
# episode 235 reward 16 loss 0.2068016082048416 epsilon 0.7896874231428072 memory 4533
# action 1 q-value 1.4388102293014526
# action 1 q-value 1.3846875429153442
# action 1 q-value 1.2853434085845947
# action 1 q-value 0.8550474643707275
# action 0 q-value 0.9170199036598206
# action 2 q-value 0.7899475693702698
# action 0 q-value 0.8980029225349426
# episode 236 reward 22 loss 0.21654607355594635 epsilon 0.7888977357196644 memory 4557
# action 1 q-value 1.4333158731460571
# action 1 q-value 1.4468663930892944
# episode 237 reward 16 loss 0.18727770447731018 epsilon 0.7881088379839447 memory 4575
# action 1 q-value 1.4276058673858643
# action 1 q-value 1.2925543785095215
# action 2 q-value 0.8702006936073303
# action 2 q-value 0.7620842456817627
# action 3 q-value 0.8734378218650818
# action 0 q-value 0.9149507880210876
# episode 238 reward 16 loss 0.18709319829940796 epsilon 0.7873207291459607 memory 4593
# action 1 q-value 1.5124776363372803
# action 3 q-value 0.8275119066238403
# action 0 q-value 0.9811407923698425
# action 1 q-value 0.6580779552459717
# episode 239 reward 14 loss 0.2285166233778 epsilon 0.7865334084168147 memory 4609
# episode 240 reward 14 loss 0.16645924746990204 epsilon 0.7857468750083979 memory 4625
# action 0 q-value 0.9035297632217407
# action 2 q-value 0.7791235446929932
# action 0 q-value 0.7652313709259033
# action 3 q-value 0.7581254839897156
# episode 241 reward 19 loss 0.22344815731048584 epsilon 0.7849611281333895 memory 4646
# action 1 q-value 1.424556016921997
# action 0 q-value 0.9529284238815308
# episode 242 reward 16 loss 0.2161104381084442 epsilon 0.784176167005256 memory 4664
# action 1 q-value 0.824630081653595
# action 2 q-value 0.7920129299163818
# episode 243 reward 14 loss 0.18161356449127197 epsilon 0.7833919908382508 memory 4680
# action 0 q-value 0.9527313709259033
# action 2 q-value 0.6661018133163452
# action 2 q-value 0.8361205458641052
# action 0 q-value 0.8504232168197632
# episode 244 reward 16 loss 0.19085043668746948 epsilon 0.7826085988474126 memory 4698
# action 1 q-value 1.4273021221160889
# action 2 q-value 1.3740726709365845
# action 0 q-value 1.108636736869812
# action 2 q-value 0.831180989742279
# action 3 q-value 0.7421616911888123
# action 2 q-value 0.8068140149116516
# action 2 q-value 0.8357453346252441
# action 0 q-value 0.7640424966812134
# episode 245 reward 19 loss 0.16084159910678864 epsilon 0.7818259902485653 memory 4719
# action 1 q-value 1.2850925922393799
# action 2 q-value 0.8063923716545105
# action 3 q-value 0.7319990992546082
# episode 246 reward 19 loss 0.20172137022018433 epsilon 0.7810441642583167 memory 4740
# action 1 q-value 1.2329864501953125
# action 1 q-value 1.2486056089401245
# action 2 q-value 1.4009896516799927
# action 0 q-value 0.7694556713104248
# episode 247 reward 16 loss 0.1718110293149948 epsilon 0.7802631200940584 memory 4758
# action 1 q-value 0.8035787343978882
# action 2 q-value 0.7786605358123779
# episode 248 reward 21 loss 0.17929111421108246 epsilon 0.7794828569739644 memory 4781
# action 0 q-value 0.9299736618995667
# action 0 q-value 0.7849549651145935
# episode 249 reward 16 loss 0.18053333461284637 epsilon 0.7787033741169904 memory 4799
# action 1 q-value 1.36124587059021
# action 1 q-value 1.2963151931762695
# action 2 q-value 0.8721096515655518
# action 0 q-value 0.9642974734306335
# action 1 q-value 0.8632186055183411
# update weights
# Avarage loss 0.19591000646352769
# episode 250 reward 19 loss 0.1722472906112671 epsilon 0.7779246707428734 memory 4820
# action 1 q-value 1.6259212493896484
# action 2 q-value 0.7857616543769836
# action 2 q-value 0.7545578479766846
# episode 251 reward 14 loss 0.24098587036132812 epsilon 0.7771467460721305 memory 4836
# action 2 q-value 0.9602723121643066
# action 0 q-value 0.6401840448379517
# action 3 q-value 0.6635519862174988
# episode 252 reward 26 loss 0.2530260682106018 epsilon 0.7763695993260584 memory 4864
# action 1 q-value 1.4563865661621094
# action 1 q-value 1.3820182085037231
# action 3 q-value 0.8667492866516113
# action 2 q-value 0.9732847213745117
# action 1 q-value 0.8217047452926636
# action 0 q-value 0.82973313331604
# action 1 q-value 0.6710501313209534
# episode 253 reward 15 loss 0.25447142124176025 epsilon 0.7755932297267324 memory 4881
# action 1 q-value 1.5633785724639893
# action 3 q-value 0.7886868119239807
# action 2 q-value 0.890975296497345
# action 2 q-value 0.7528342008590698
# episode 254 reward 14 loss 0.2343188375234604 epsilon 0.7748176364970056 memory 4897
# action 2 q-value 0.8729369044303894
# episode 255 reward 14 loss 0.23131395876407623 epsilon 0.7740428188605086 memory 4913
# action 1 q-value 1.379547119140625
# action 2 q-value 1.0115786790847778
# action 3 q-value 1.0689042806625366
# action 2 q-value 0.8656612038612366
# action 0 q-value 0.9515096545219421
# action 0 q-value 0.8268886208534241
# episode 256 reward 16 loss 0.21357318758964539 epsilon 0.7732687760416481 memory 4931
# action 1 q-value 1.4928193092346191
# action 2 q-value 0.9940119981765747
# episode 257 reward 19 loss 0.18987858295440674 epsilon 0.7724955072656065 memory 4952
# action 1 q-value 1.4727944135665894
# action 0 q-value 1.0433928966522217
# action 0 q-value 0.848150372505188
# episode 258 reward 18 loss 0.20586717128753662 epsilon 0.7717230117583408 memory 4972
# action 2 q-value 1.5662175416946411
# action 0 q-value 0.9354135394096375
# action 2 q-value 0.9087298512458801
# action 2 q-value 0.9433183073997498
# action 0 q-value 0.8953859210014343
# action 2 q-value 0.691256582736969
# action 0 q-value 0.9459215402603149
# episode 259 reward 19 loss 0.20079952478408813 epsilon 0.7709512887465825 memory 4993
# action 1 q-value 1.505051851272583
# action 3 q-value 1.2489169836044312
# action 2 q-value 0.9819676876068115
# action 3 q-value 0.9420819878578186
# action 2 q-value 0.8815068006515503
# action 0 q-value 0.832676351070404
# action 0 q-value 0.8571430444717407
# action 2 q-value 0.8595162630081177
# action 0 q-value 0.6877974271774292
# episode 260 reward 20 loss 0.23904086649417877 epsilon 0.7701803374578359 memory 5015
# action 2 q-value 1.0862747430801392
# action 0 q-value 0.9344508647918701
# episode 261 reward 16 loss 0.18205827474594116 epsilon 0.7694101571203781 memory 5033
# action 1 q-value 1.3246227502822876
# action 2 q-value 0.9667758941650391
# action 0 q-value 0.802392840385437
# action 2 q-value 0.8244031071662903
# action 2 q-value 0.6781079769134521
# episode 262 reward 16 loss 0.23464922606945038 epsilon 0.7686407469632577 memory 5051
# action 1 q-value 1.5378183126449585
# action 1 q-value 1.4865283966064453
# action 1 q-value 1.4888426065444946
# action 3 q-value 0.9389840364456177
# action 0 q-value 1.020793080329895
# action 2 q-value 0.7365784645080566
# action 3 q-value 0.8249017596244812
# action 3 q-value 0.7554498910903931
# episode 263 reward 15 loss 0.228454127907753 epsilon 0.7678721062162944 memory 5068
# action 1 q-value 1.5584808588027954
# action 2 q-value 1.0034159421920776
# action 2 q-value 0.9273869395256042
# action 2 q-value 0.8224172592163086
# episode 264 reward 16 loss 0.20598390698432922 epsilon 0.7671042341100781 memory 5086
# action 3 q-value 1.4171587228775024
# action 1 q-value 1.5894707441329956
# action 3 q-value 0.83823162317276
# action 3 q-value 0.9642977118492126
# action 0 q-value 0.9736034870147705
# episode 265 reward 16 loss 0.20775149762630463 epsilon 0.766337129875968 memory 5104
# action 1 q-value 1.3977476358413696
# action 0 q-value 0.9233207106590271
# action 1 q-value 0.8029460906982422
# action 0 q-value 0.7613210678100586
# episode 266 reward 14 loss 0.18445713818073273 epsilon 0.7655707927460921 memory 5120
# action 2 q-value 0.9307622909545898
# episode 267 reward 16 loss 0.17439526319503784 epsilon 0.764805221953346 memory 5138
# action 1 q-value 1.6837741136550903
# action 3 q-value 1.1233776807785034
# action 3 q-value 0.9149139523506165
# action 2 q-value 1.0450135469436646
# action 0 q-value 0.8930180072784424
# episode 268 reward 22 loss 0.17841553688049316 epsilon 0.7640404167313927 memory 5162
# action 2 q-value 0.9166840314865112
# action 2 q-value 1.0171047449111938
# action 0 q-value 0.8095442652702332
# action 2 q-value 0.913557231426239
# episode 269 reward 20 loss 0.18986722826957703 epsilon 0.7632763763146613 memory 5184
# action 1 q-value 1.7024707794189453
# action 0 q-value 0.9041134119033813
# action 3 q-value 0.8882550001144409
# action 2 q-value 1.0610905885696411
# action 0 q-value 1.0614410638809204
# episode 270 reward 19 loss 0.19272422790527344 epsilon 0.7625130999383466 memory 5205
# action 0 q-value 1.6795775890350342
# action 1 q-value 1.5492336750030518
# action 2 q-value 1.0882965326309204
# action 2 q-value 0.9424433708190918
# action 3 q-value 1.0171579122543335
# action 0 q-value 0.8351855874061584
# action 0 q-value 0.7771656513214111
# episode 271 reward 17 loss 0.20244355499744415 epsilon 0.7617505868384082 memory 5224
# action 0 q-value 1.18132746219635
# action 2 q-value 0.8707894682884216
# action 2 q-value 0.9360709190368652
# episode 272 reward 16 loss 0.19076678156852722 epsilon 0.7609888362515699 memory 5242
# action 1 q-value 1.604768991470337
# action 1 q-value 1.5896897315979004
# action 1 q-value 1.7853683233261108
# action 0 q-value 1.0658695697784424
# action 2 q-value 0.9695538878440857
# action 2 q-value 0.9597517251968384
# episode 273 reward 16 loss 0.17425860464572906 epsilon 0.7602278474153183 memory 5260
# action 0 q-value 1.6723591089248657
# action 0 q-value 0.8851394057273865
# action 0 q-value 0.9269638061523438
# action 0 q-value 0.9805629849433899
# episode 274 reward 16 loss 0.15371263027191162 epsilon 0.759467619567903 memory 5278
# action 0 q-value 1.6597052812576294
# action 1 q-value 1.566247820854187
# action 0 q-value 0.9447872638702393
# action 3 q-value 0.9516317844390869
# action 1 q-value 0.7772035598754883
# action 2 q-value 0.8988511562347412
# action 0 q-value 1.0017069578170776
# episode 275 reward 15 loss 0.1752510666847229 epsilon 0.7587081519483351 memory 5295
# action 3 q-value 0.9053124189376831
# ...
# action 0 q-value 5.595396041870117
# action 3 q-value 5.3978352546691895
# action 3 q-value 5.61679220199585
# action 2 q-value 5.0091376304626465
# action 2 q-value 2.7513251304626465
# action 2 q-value 4.4224090576171875
# action 2 q-value 3.242497444152832
# action 1 q-value 4.6861701011657715
# action 2 q-value 4.544151306152344
# action 1 q-value 4.142328262329102
# action 2 q-value 3.1880674362182617
# episode 861 reward 24 loss 0.2131236344575882 epsilon 0.42213450329202495 memory 16653
# action 3 q-value 5.296616077423096
# action 3 q-value 5.171860218048096
# action 1 q-value 5.152174949645996
# action 3 q-value 5.137855052947998
# action 1 q-value 5.632537841796875
# action 1 q-value 5.556024551391602
# action 1 q-value 4.381028652191162
# action 0 q-value 4.139575004577637
# action 2 q-value 4.34785270690918
# action 1 q-value 2.9876487255096436
# action 1 q-value 4.805712699890137
# action 1 q-value 4.426815032958984
# action 2 q-value 2.7196810245513916
# episode 862 reward 20 loss 0.16955816745758057 epsilon 0.4217123687887329 memory 16675
# action 3 q-value 5.304743766784668
# action 3 q-value 5.104621410369873
# action 1 q-value 4.3561224937438965
# action 1 q-value 5.30805778503418
# action 2 q-value 5.856648921966553
# action 0 q-value 4.723987579345703
# action 2 q-value 4.598240852355957
# action 3 q-value 4.448680400848389
# action 1 q-value 4.343933582305908
# action 2 q-value 2.1783974170684814
# episode 863 reward 17 loss 0.15846538543701172 epsilon 0.4212906564199442 memory 16694
# action 3 q-value 5.307888984680176
# action 1 q-value 4.7488484382629395
# action 2 q-value 4.698731899261475
# action 3 q-value 5.416984558105469
# action 2 q-value 5.473946571350098
# action 1 q-value 5.311323165893555
# action 3 q-value 5.6531572341918945
# action 2 q-value 5.840882301330566
# action 1 q-value 5.0275750160217285
# action 2 q-value 5.046724796295166
# action 2 q-value 3.9616036415100098
# action 2 q-value 1.7983226776123047
# episode 864 reward 13 loss 0.2870883345603943 epsilon 0.42086936576352424 memory 16709
# action 2 q-value 4.805526256561279
# action 1 q-value 4.772104263305664
# action 2 q-value 4.773838520050049
# action 2 q-value 5.067223072052002
# action 2 q-value 4.14837646484375
# action 1 q-value 3.949767827987671
# episode 865 reward 15 loss 0.3926757872104645 epsilon 0.4204484963977607 memory 16726
# action 2 q-value 4.789031028747559
# action 3 q-value 4.813424110412598
# action 1 q-value 4.543827056884766
# action 2 q-value 5.206695079803467
# action 1 q-value 5.088973522186279
# action 1 q-value 5.574749946594238
# action 3 q-value 5.39837121963501
# action 1 q-value 5.326648235321045
# action 1 q-value 5.431384086608887
# action 1 q-value 4.431175231933594
# action 2 q-value 3.658374547958374
# action 1 q-value 3.5465235710144043
# action 2 q-value 2.4743638038635254
# episode 866 reward 17 loss 0.196822389960289 epsilon 0.42002804790136294 memory 16745
# action 3 q-value 5.271614074707031
# action 1 q-value 4.537170886993408
# action 3 q-value 4.699630260467529
# action 1 q-value 5.091548442840576
# action 3 q-value 4.71312952041626
# action 1 q-value 5.231973171234131
# action 1 q-value 6.032259464263916
# action 1 q-value 4.876253128051758
# action 0 q-value 2.513909339904785
# action 0 q-value 2.9806408882141113
# action 1 q-value 3.1859934329986572
# action 0 q-value 2.854459762573242
# action 1 q-value 1.960712194442749
# episode 867 reward 24 loss 0.1880396455526352 epsilon 0.4196080198534616 memory 16771
# action 3 q-value 5.250914096832275
# action 1 q-value 4.490200042724609
# action 2 q-value 4.5883684158325195
# action 1 q-value 5.543817520141602
# action 1 q-value 5.530182838439941
# action 1 q-value 5.82061243057251
# action 1 q-value 5.398768424987793
# action 1 q-value 4.25818395614624
# episode 868 reward 13 loss 0.22761142253875732 epsilon 0.4191884118336081 memory 16786
# action 3 q-value 5.257962703704834
# action 1 q-value 4.725265026092529
# action 3 q-value 4.966599464416504
# action 1 q-value 6.024460315704346
# action 1 q-value 6.175887107849121
# action 1 q-value 5.876499652862549
# action 1 q-value 6.376333713531494
# action 1 q-value 6.033761024475098
# action 1 q-value 5.763983249664307
# action 0 q-value 5.6961212158203125
# action 1 q-value 4.451213359832764
# action 0 q-value 0.7478594183921814
# episode 869 reward 13 loss 0.11148697137832642 epsilon 0.41876922342177453 memory 16801
# action 1 q-value 4.636270523071289
# action 1 q-value 5.6323957443237305
# action 1 q-value 5.585947513580322
# action 1 q-value 6.080989837646484
# action 1 q-value 5.987193584442139
# action 1 q-value 5.940023899078369
# action 1 q-value 5.647579193115234
# action 0 q-value 5.451539039611816
# action 1 q-value 5.334653377532959
# action 1 q-value 4.327813148498535
# episode 870 reward 14 loss 0.16645118594169617 epsilon 0.41835045419835276 memory 16817
# action 3 q-value 5.422274112701416
# action 1 q-value 4.727534294128418
# action 0 q-value 5.606059551239014
# action 1 q-value 6.114513874053955
# action 1 q-value 6.074842929840088
# action 1 q-value 6.151943206787109
# action 1 q-value 4.40733003616333
# action 0 q-value 3.669375419616699
# action 0 q-value 4.13107442855835
# action 1 q-value 4.499671459197998
# action 1 q-value 5.515054702758789
# action 1 q-value 3.692256450653076
# action 0 q-value 5.074220180511475
# action 1 q-value 4.3650054931640625
# episode 871 reward 22 loss 0.2270304262638092 epsilon 0.4179321037441544 memory 16841
# action 3 q-value 5.507474422454834
# action 0 q-value 5.054531097412109
# action 3 q-value 5.652712345123291
# action 1 q-value 5.357328414916992
# action 1 q-value 6.048986911773682
# action 1 q-value 6.417142868041992
# action 1 q-value 6.528096675872803
# action 1 q-value 5.725072383880615
# action 1 q-value 5.59598970413208
# action 1 q-value 3.3505825996398926
# episode 872 reward 13 loss 0.1967502236366272 epsilon 0.41751417164041027 memory 16856
# action 3 q-value 5.229063034057617
# action 3 q-value 5.233068466186523
# action 3 q-value 5.197009086608887
# action 1 q-value 5.230193614959717
# action 3 q-value 5.394130706787109
# action 1 q-value 6.071964740753174
# action 1 q-value 5.883852958679199
# action 1 q-value 6.185537338256836
# episode 873 reward 13 loss 0.18958446383476257 epsilon 0.41709665746876984 memory 16871
# action 3 q-value 5.639654636383057
# action 3 q-value 4.9613752365112305
# action 3 q-value 5.6515583992004395
# action 3 q-value 6.200015544891357
# action 1 q-value 6.27935266494751
# action 1 q-value 6.291975021362305
# action 1 q-value 5.817140579223633
# action 1 q-value 4.90287971496582
# action 0 q-value 1.5503628253936768
# episode 874 reward 14 loss 0.20444758236408234 epsilon 0.4166795608113011 memory 16887
# action 3 q-value 5.656716346740723
# action 1 q-value 5.622442245483398
# action 3 q-value 5.283175945281982
# action 3 q-value 6.002233028411865
# action 1 q-value 6.294765949249268
# action 1 q-value 5.973893165588379
# action 1 q-value 5.501523017883301
# action 0 q-value 2.899888038635254
# action 1 q-value 4.371248245239258
# action 1 q-value 4.658726692199707
# action 0 q-value 3.518425226211548
# action 1 q-value 5.258267879486084
# action 1 q-value 4.806081771850586
# episode 875 reward 22 loss 0.13438239693641663 epsilon 0.41626288125048977 memory 16911
# action 3 q-value 5.64559268951416
# action 3 q-value 5.930372714996338
# action 0 q-value 5.125627517700195
# action 1 q-value 6.1500043869018555
# action 1 q-value 6.333055019378662
# action 1 q-value 5.939330101013184
# action 1 q-value 6.350688457489014
# action 1 q-value 5.877697467803955
# action 1 q-value 5.826966285705566
# action 1 q-value 5.370968818664551
# action 1 q-value 5.09717321395874
# action 1 q-value 3.2411155700683594
# action 0 q-value 0.5931923389434814
# episode 876 reward 13 loss 0.2524322271347046 epsilon 0.41584661836923925 memory 16926
# action 3 q-value 5.373317241668701
# action 3 q-value 5.089256286621094
# action 2 q-value 5.722588539123535
# action 1 q-value 5.848292827606201
# action 1 q-value 5.86370849609375
# action 1 q-value 5.913283348083496
# action 1 q-value 6.132022857666016
# action 1 q-value 5.679590225219727
# action 1 q-value 5.877091407775879
# action 3 q-value 4.712501525878906
# episode 877 reward 14 loss 0.10212291777133942 epsilon 0.41543077175087 memory 16942
# action 3 q-value 5.08057975769043
# action 3 q-value 5.196271896362305
# action 3 q-value 5.582958221435547
# action 3 q-value 6.211317539215088
# action 1 q-value 6.041128158569336
# action 1 q-value 4.294661998748779
# action 0 q-value 2.3757288455963135
# action 1 q-value 5.82867956161499
# action 0 q-value 3.8990237712860107
# action 3 q-value 5.2020344734191895
# action 1 q-value 4.753777027130127
# episode 878 reward 24 loss 0.1254139542579651 epsilon 0.41501534097911913 memory 16968
# action 2 q-value 5.0816874504089355
# action 3 q-value 5.243084907531738
# action 1 q-value 4.9394025802612305
# action 1 q-value 5.2531208992004395
# action 3 q-value 6.387353420257568
# action 3 q-value 6.302799701690674
# action 1 q-value 6.10973596572876
# action 3 q-value 6.727069854736328
# action 3 q-value 6.035236835479736
# action 3 q-value 6.1521525382995605
# action 3 q-value 4.6838483810424805
# action 0 q-value 2.9065327644348145
# action 1 q-value 5.828505516052246
# action 3 q-value 4.101316928863525
# action 3 q-value 3.3170599937438965
# episode 879 reward 19 loss 0.17894116044044495 epsilon 0.41460032563814003 memory 16989
# action 2 q-value 5.713989734649658
# action 2 q-value 4.988420009613037
# action 1 q-value 4.9882612228393555
# action 1 q-value 5.882081508636475
# action 3 q-value 5.913797855377197
# action 3 q-value 6.112928867340088
# action 3 q-value 6.245138645172119
# action 3 q-value 5.728529930114746
# action 2 q-value 5.382174968719482
# action 1 q-value 4.035993576049805
# action 0 q-value 4.166411876678467
# action 1 q-value 5.04244327545166
# action 2 q-value 5.444263935089111
# action 3 q-value 4.97910737991333
# action 0 q-value 3.7581517696380615
# action 1 q-value 3.8632442951202393
# episode 880 reward 22 loss 0.11378458142280579 epsilon 0.4141857253125019 memory 17013
# action 2 q-value 5.73382568359375
# action 3 q-value 5.186670303344727
# action 3 q-value 4.8464884757995605
# action 1 q-value 4.772848129272461
# action 3 q-value 6.523818492889404
# action 2 q-value 6.211960315704346
# action 2 q-value 5.655261039733887
# action 1 q-value 5.212912559509277
# action 1 q-value 3.6739184856414795
# action 0 q-value 0.4957829713821411
# episode 881 reward 15 loss 0.12096817791461945 epsilon 0.41377153958718943 memory 17030
# action 2 q-value 5.293429851531982
# action 3 q-value 5.594815254211426
# action 2 q-value 6.387340545654297
# action 3 q-value 5.9117255210876465
# action 3 q-value 6.266263484954834
# action 3 q-value 6.199192047119141
# action 2 q-value 6.122544288635254
# action 2 q-value 5.301466464996338
# action 3 q-value 4.311801433563232
# action 2 q-value 2.5236141681671143
# episode 882 reward 13 loss 0.13776053488254547 epsilon 0.4133577680476022 memory 17045
# action 2 q-value 5.830842018127441
# action 2 q-value 4.689380168914795
# action 3 q-value 4.589925765991211
# action 3 q-value 5.605127811431885
# action 2 q-value 5.665696620941162
# action 2 q-value 6.234268665313721
# action 2 q-value 6.24918270111084
# action 2 q-value 5.758481502532959
# action 3 q-value 5.600851535797119
# action 2 q-value 3.171513557434082
# action 1 q-value 5.561551094055176
# action 2 q-value 4.211548328399658
# episode 883 reward 20 loss 0.09242106974124908 epsilon 0.4129444102795546 memory 17067
# action 2 q-value 5.14509391784668
# action 1 q-value 4.976377010345459
# action 2 q-value 6.3748779296875
# action 2 q-value 6.15739107131958
# action 2 q-value 6.140474796295166
# action 1 q-value 6.34229040145874
# action 1 q-value 5.075815200805664
# action 2 q-value 3.559028148651123
# action 2 q-value 4.7268853187561035
# action 2 q-value 5.097757339477539
# action 1 q-value 4.294841289520264
# action 2 q-value 5.143631935119629
# action 1 q-value 7.10232400894165
# action 2 q-value 4.416822910308838
# action 2 q-value 2.3310086727142334
# episode 884 reward 25 loss 0.23475030064582825 epsilon 0.412531465869275 memory 17094
# action 2 q-value 5.960608005523682
# action 2 q-value 5.278825759887695
# action 1 q-value 5.001986026763916
# action 2 q-value 5.338766574859619
# action 3 q-value 5.744350910186768
# action 2 q-value 6.319381237030029
# action 3 q-value 6.2528533935546875
# action 1 q-value 6.56557559967041
# action 3 q-value 6.896310329437256
# action 2 q-value 6.694359302520752
# action 3 q-value 2.8939473628997803
# episode 885 reward 14 loss 0.23717591166496277 epsilon 0.41211893440340575 memory 17110
# action 2 q-value 5.996379852294922
# action 3 q-value 5.041697025299072
# action 3 q-value 6.307352066040039
# action 2 q-value 6.672811985015869
# action 3 q-value 4.683382511138916
# action 2 q-value 5.557070732116699
# action 2 q-value 5.280349254608154
# action 2 q-value 5.741645812988281
# action 1 q-value 5.647171974182129
# action 1 q-value 4.426397323608398
# action 2 q-value 5.433168411254883
# action 2 q-value 4.533505916595459
# action 1 q-value 4.56832218170166
# action 2 q-value 6.53797721862793
# action 3 q-value 3.397925615310669
# episode 886 reward 30 loss 0.22871823608875275 epsilon 0.41170681546900234 memory 17142
# action 3 q-value 5.609463214874268
# action 3 q-value 5.4714436531066895
# action 2 q-value 6.777523040771484
# action 1 q-value 6.482598304748535
# action 2 q-value 6.321333885192871
# action 1 q-value 5.970917224884033
# action 1 q-value 4.988142013549805
# action 2 q-value 5.119466304779053
# action 0 q-value 3.273660659790039
# action 1 q-value 4.403404712677002
# action 2 q-value 4.841484069824219
# action 1 q-value 6.7272467613220215
# action 3 q-value 4.406786918640137
# episode 887 reward 22 loss 0.16533911228179932 epsilon 0.41129510865353336 memory 17166
# action 1 q-value 5.300901412963867
# action 2 q-value 6.2520551681518555
# action 3 q-value 6.237626552581787
# action 3 q-value 6.204801559448242
# action 3 q-value 6.42259407043457
# action 2 q-value 6.108954906463623
# action 1 q-value 6.536256790161133
# action 2 q-value 6.267574787139893
# action 3 q-value 4.914806842803955
# action 2 q-value 4.004483699798584
# action 2 q-value 6.877979278564453
# action 1 q-value 4.1947736740112305
# episode 888 reward 22 loss 0.1945873200893402 epsilon 0.41088381354487985 memory 17190
# action 2 q-value 6.027308464050293
# action 3 q-value 5.535742282867432
# action 0 q-value 5.646709442138672
# action 1 q-value 6.277853012084961
# action 2 q-value 6.400989532470703
# action 1 q-value 6.122384071350098
# action 3 q-value 6.021683216094971
# action 2 q-value 6.26457405090332
# action 2 q-value 1.784360647201538
# episode 889 reward 15 loss 0.17445990443229675 epsilon 0.410472929731335 memory 17207
# action 0 q-value 6.180917263031006
# action 1 q-value 5.551169395446777
# action 2 q-value 5.947310924530029
# action 1 q-value 5.205796718597412
# action 1 q-value 6.167971611022949
# action 2 q-value 6.147950649261475
# action 1 q-value 5.995198726654053
# action 1 q-value 5.889699459075928
# action 1 q-value 3.8631272315979004
# episode 890 reward 15 loss 0.13510966300964355 epsilon 0.41006245680160364 memory 17224
# action 0 q-value 6.281492710113525
# action 2 q-value 5.595732688903809
# action 3 q-value 6.0429463386535645
# action 2 q-value 5.668431758880615
# action 1 q-value 6.359122276306152
# action 1 q-value 6.215265274047852
# action 1 q-value 5.582845211029053
# action 2 q-value 5.740235328674316
# action 2 q-value 3.369320869445801
# episode 891 reward 15 loss 0.09066116809844971 epsilon 0.40965239434480205 memory 17241
# action 0 q-value 6.388303279876709
# action 2 q-value 5.703118801116943
# action 3 q-value 5.887348651885986
# action 1 q-value 5.588993549346924
# action 1 q-value 5.7810282707214355
# action 1 q-value 6.18803596496582
# action 1 q-value 6.463014125823975
# action 1 q-value 6.240551471710205
# action 1 q-value 5.9857354164123535
# action 2 q-value 2.5740082263946533
# action 1 q-value 5.809623718261719
# action 2 q-value 4.331089019775391
# action 3 q-value 4.675076007843018
# action 1 q-value 5.485374927520752
# action 3 q-value 3.9084205627441406
# action 2 q-value 3.7613821029663086
